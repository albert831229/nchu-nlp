# %% [markdown]
# # Upload dataset and preprocess it

# %% [markdown]
# # Build and train your model

# %% [markdown]
# # Evaluate your model with F1 score. (Show your "true" performance, i.e. ignore the padding)

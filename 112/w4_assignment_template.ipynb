# %% [markdown]
# # Please select a dataset from Kaggle and describe what type of recommender system you want to build (20%)

# %% [markdown]
# # How do you combine your data into a single string? (i.e., as the input for you TfidfVectorizer) (20%)

# %% [markdown]
# # Transform the strings using TF-IDF (10%)

# %% [markdown]
# # Given a query: (50%)
# - Get TF-IDF representation of the query
# - Compute the similarity between the query and all other vectors
# - Sort by similarity
# - Print out the top 5 closest recommendations
